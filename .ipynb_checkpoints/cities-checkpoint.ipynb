# %%
import pandas as pd
  
# to read csv file named "samplee"
a = pd.read_csv("Resources/cities.csv")
  
# to save as html file
# named as "Table"
a.to_html("cities.htm")
  
# assign it to a 
# variable (string)
html_file = a.to_html()

# %%
print(a.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>North Bend</td>
#       <td>43.4065</td>
#       <td>-124.2243</td>
#       <td>42.80</td>
#       <td>87</td>
#       <td>90</td>
#       <td>9.22</td>
#       <td>US</td>
#       <td>1613798030</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Tiksi</td>
#       <td>71.6872</td>
#       <td>128.8694</td>
#       <td>-29.81</td>
#       <td>85</td>
#       <td>98</td>
#       <td>2.55</td>
#       <td>RU</td>
#       <td>1613797862</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>East London</td>
#       <td>-33.0153</td>
#       <td>27.9116</td>
# ...
